# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from warnings import filterwarnings
filterwarnings('ignore')

# %%
fifa=pd.read_csv(r"C:\Users\shank\Downloads\fifa.csv")

# %%
fifa.head(2)
# Out:
#        ID               Name  Age  \
# 0  158023           L. Messi   31
# 1   20801  Cristiano Ronaldo   33
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
#
#                                   Flag  Overall  Potential          Club  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94  FC Barcelona
# 1  https://cdn.sofifa.org/flags/38.png       94         94      Juventus
#
#                                       Club Logo  ... Composure Marking  \
# 0  https://cdn.sofifa.org/teams/2/light/241.png  ...      96.0    33.0
# 1   https://cdn.sofifa.org/teams/2/light/45.png  ...      95.0    28.0
#
#   StandingTackle  SlidingTackle  GKDiving  GKHandling GKKicking GKPositioning  \
# 0           28.0           26.0       6.0        11.0      15.0          14.0
# ...

# %%
fifa.columns
# Out:
# Index(['ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag', 'Overall',
#        'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Preferred Foot',
#        'International Reputation', 'Weak Foot', 'Skill Moves', 'Work Rate',
#        'Body Type', 'Position', 'Jersey Number', 'Joined', 'Loaned From',
#        'Contract Valid Until', 'Height', 'Weight', 'Crossing', 'Finishing',
#        'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling', 'Curve',
#        'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
#        'Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving', 'GKHandling',
#        'GKKicking', 'GKPositioning', 'GKReflexes', 'Release Clause'],
#       dtype='object')

# %%
fifa=fifa.drop('Photo',axis=1)
fifa=fifa.drop('Flag',axis=1)
fifa=fifa.drop('Club Logo',axis=1)
fifa=fifa.drop('ID',axis=1)
fifa=fifa.drop('Nationality',axis=1)
fifa=fifa.drop('Preferred Foot',axis=1)

#Overall, Value, Wage, International Reputation, Height, Weight, Release Clause

# %%
drop_list=['Weak Foot','Jersey Number','Dribbling','Curve']

# %%
fifa=fifa.drop(drop_list,axis=1)

# %%
drop_list2=['Composure','Marking','StandingTackle','SlidingTackle','GKDiving','GKHandling','GKKicking','GKPositioning','GKReflexes']
fifa=fifa.drop(drop_list2,axis=1)

# %%
fifa.head(5)
# Out:
#                 Name  Age  Overall  Potential                 Club    Value  \
# 0           L. Messi   31       94         94         FC Barcelona  €110.5M
# 1  Cristiano Ronaldo   33       94         94             Juventus     €77M
# 2          Neymar Jr   26       92         93  Paris Saint-Germain  €118.5M
# 3             De Gea   27       91         93    Manchester United     €72M
# 4       K. De Bruyne   27       91         92      Manchester City    €102M
#
#     Wage  International Reputation  Skill Moves       Work Rate  ... Jumping  \
# 0  €565K                       5.0          4.0  Medium/ Medium  ...    68.0
# 1  €405K                       5.0          5.0       High/ Low  ...    95.0
# 2  €290K                       5.0          5.0    High/ Medium  ...    61.0
# 3  €260K                       4.0          1.0  Medium/ Medium  ...    67.0
# 4  €355K                       4.0          4.0      High/ High  ...    63.0
#
# ...

# %%
drop_list3=['Jumping','Stamina','Strength','LongShots','Aggression','Interceptions','Positioning','Vision','Penalties']
fifa=fifa.drop(drop_list3,axis=1)

# %%
fifa.head(5)
# Out:
#                 Name  Age  Overall  Potential                 Club    Value  \
# 0           L. Messi   31       94         94         FC Barcelona  €110.5M
# 1  Cristiano Ronaldo   33       94         94             Juventus     €77M
# 2          Neymar Jr   26       92         93  Paris Saint-Germain  €118.5M
# 3             De Gea   27       91         93    Manchester United     €72M
# 4       K. De Bruyne   27       91         92      Manchester City    €102M
#
#     Wage  International Reputation  Skill Moves       Work Rate  ...  \
# 0  €565K                       5.0          4.0  Medium/ Medium  ...
# 1  €405K                       5.0          5.0       High/ Low  ...
# 2  €290K                       5.0          5.0    High/ Medium  ...
# 3  €260K                       4.0          1.0  Medium/ Medium  ...
# 4  €355K                       4.0          4.0      High/ High  ...
#
#   FKAccuracy LongPassing BallControl Acceleration SprintSpeed Agility  \
# ...

# %%
drop_list4=['FKAccuracy','LongPassing','BallControl','Acceleration','SprintSpeed','Agility','Reactions','Balance','ShotPower']
fifa=fifa.drop(drop_list4,axis=1)

# %%
fifa.head(5)
# Out:
#                 Name  Age  Overall  Potential                 Club    Value  \
# 0           L. Messi   31       94         94         FC Barcelona  €110.5M
# 1  Cristiano Ronaldo   33       94         94             Juventus     €77M
# 2          Neymar Jr   26       92         93  Paris Saint-Germain  €118.5M
# 3             De Gea   27       91         93    Manchester United     €72M
# 4       K. De Bruyne   27       91         92      Manchester City    €102M
#
#     Wage  International Reputation  Skill Moves       Work Rate  ...  \
# 0  €565K                       5.0          4.0  Medium/ Medium  ...
# 1  €405K                       5.0          5.0       High/ Low  ...
# 2  €290K                       5.0          5.0    High/ Medium  ...
# 3  €260K                       4.0          1.0  Medium/ Medium  ...
# 4  €355K                       4.0          4.0      High/ High  ...
#
#   Loaned From Contract Valid Until Height  Weight Crossing Finishing  \
# ...

# %%
drop_list5=['Crossing','Finishing','HeadingAccuracy','ShortPassing','Volleys']
fifa=fifa.drop(drop_list5,axis=1)

# %%
fifa.head(5)
# Out:
#                 Name  Age  Overall  Potential                 Club    Value  \
# 0           L. Messi   31       94         94         FC Barcelona  €110.5M
# 1  Cristiano Ronaldo   33       94         94             Juventus     €77M
# 2          Neymar Jr   26       92         93  Paris Saint-Germain  €118.5M
# 3             De Gea   27       91         93    Manchester United     €72M
# 4       K. De Bruyne   27       91         92      Manchester City    €102M
#
#     Wage  International Reputation  Skill Moves       Work Rate   Body Type  \
# 0  €565K                       5.0          4.0  Medium/ Medium       Messi
# 1  €405K                       5.0          5.0       High/ Low  C. Ronaldo
# 2  €290K                       5.0          5.0    High/ Medium      Neymar
# 3  €260K                       4.0          1.0  Medium/ Medium        Lean
# 4  €355K                       4.0          4.0      High/ High      Normal
#
# ...

# %%
fifa['Wage'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0        €565K
# 1        €405K
# 2        €290K
# 3        €260K
# 4        €355K
#          ...
# 18202      €1K
# 18203      €1K
# 18204      €1K
# 18205      €1K
# 18206      €1K
# Name: Wage, Length: 18207, dtype: object>

# %%
fifa['Wage'].dtype
# Out:
# dtype('O')

# %%
fifa['Wage']=fifa['Wage'].str.replace('€','')

# %%
fifa['Wage'].value_counts()
# Out:
# 1K      4900
# 2K      2827
# 3K      1857
# 4K      1255
# 5K       869
#         ...
# 245K       1
# 190K       1
# 200K       1
# 235K       1
# 250K       1
# Name: Wage, Length: 144, dtype: int64

# %%
fifa['Value']=fifa['Value'].str.replace('€','')

# %%
fifa['Value'].value_counts()
# Out:
# 1.1M    431
# 375K    372
# 425K    354
# 325K    351
# 450K    343
#        ...
# 53M       1
# 58M       1
# 72M       1
# 64M       1
# 78M       1
# Name: Value, Length: 217, dtype: int64

# %%
def convert(value):
    if value:
        multiplier = 1
        if value.endswith('K'):
            multiplier = 1000
            value = value[0:len(value)-1] 
        elif value.endswith('M'):
            multiplier = 1000000
            value = value[0:len(value)-1] 

        return float(value) * multiplier

    else:
        return 0

# %%
fifa['Value']=fifa['Value'].apply(convert)

# %%
fifa['Wage']=fifa['Wage'].apply(convert)

# %%
fifa['Value']=fifa['Value'].astype(float)

# %%
fifa['Wage']=fifa['Wage'].astype(float)

# %%
fifa['Wage']
# Out:
# 0        565000.0
# 1        405000.0
# 2        290000.0
# 3        260000.0
# 4        355000.0
#            ...
# 18202      1000.0
# 18203      1000.0
# 18204      1000.0
# 18205      1000.0
# 18206      1000.0
# Name: Wage, Length: 18207, dtype: float64

# %%
fifa['Joined'].value_counts()
# Out:
# Jul 1, 2018     1538
# Jul 1, 2017     1133
# Jan 1, 2018      635
# Jul 1, 2016      614
# Jul 1, 2015      368
#                 ...
# Aug 29, 2012       1
# Jul 26, 2010       1
# May 6, 2014        1
# Feb 18, 2017       1
# Oct 1, 2010        1
# Name: Joined, Length: 1736, dtype: int64

# %%
fifa['Joined'].dtype
# Out:
# dtype('O')

# %%
fifa['Value'].dtype
# Out:
# dtype('float64')

# %%
fifa['Wage'].dtype
# Out:
# dtype('float64')

# %%
fifa['Joined'] = pd.to_datetime(fifa['Joined'])

# %%
fifa['Joined']=fifa['Joined'].dt.year

# %%
fifa['Joined']=pd.to_numeric(fifa['Joined'])

# %%
fifa['Contract Valid Until']=pd.to_datetime(fifa['Contract Valid Until'])

# %%
fifa['Contract Valid Until'].dtype
# Out:
# dtype('<M8[ns]')

# %%
fifa['Height']
# Out:
# 0         5'7
# 1         6'2
# 2         5'9
# 3         6'4
# 4        5'11
#          ...
# 18202     5'9
# 18203     6'3
# 18204     5'8
# 18205    5'10
# 18206    5'10
# Name: Height, Length: 18207, dtype: object

# %%
fifa['Height']=fifa['Height'].str.replace("'",".")

# %%
fifa['Height']=fifa['Height'].astype(float)

# %%
fifa['Height'].dtype
# Out:
# dtype('float64')

# %%
fifa['Weight']=fifa['Weight'].str.replace('lbs','')

# %%
fifa['Weight']
# Out:
# 0        159
# 1        183
# 2        150
# 3        168
# 4        154
#         ...
# 18202    134
# 18203    170
# 18204    148
# 18205    154
# 18206    176
# Name: Weight, Length: 18207, dtype: object

# %%
fifa['Weight']=fifa['Weight'].astype(float)

# %%
fifa['Release Clause']=fifa['Release Clause'].str.replace('€','')

# %%
fifa['Release Clause'].dtype
# Out:
# dtype('O')

# %%
fifa['Release Clause_m']=fifa[fifa['Release Clause'].str.endswith('M')==True]['Release Clause'].str.replace('M','')

# %%
fifa['Release Clause_m'] = pd.to_numeric(fifa['Release Clause_m'])
Release_Clause_m=fifa['Release Clause_m']*1000000

# %%
fifa['Release Clause_k']=fifa[fifa['Release Clause'].str.endswith('K')==True]['Release Clause'].str.replace('K','')
Release_Clause_k=fifa['Release Clause_k']*1000

# %%
fifa['Release Clause']
# Out:
# 0        226.5M
# 1        127.1M
# 2        228.1M
# 3        138.6M
# 4        196.4M
#           ...
# 18202      143K
# 18203      113K
# 18204      165K
# 18205      143K
# 18206      165K
# Name: Release Clause, Length: 18207, dtype: object

# %%
fifa['Release Clause']=fifa['Release Clause'].fillna(0)

# %%
fifa['Release Clause']=fifa['Release Clause'].replace({'K':'*1e3','M':'*1e6'},regex=True).map(pd.eval)

# %%
fifa.isnull().sum()
# Out:
# Name                            0
# Age                             0
# Overall                         0
# Potential                       0
# Club                          241
# Value                           0
# Wage                            0
# International Reputation       48
# Skill Moves                    48
# Work Rate                      48
# Body Type                      48
# Position                       60
# Joined                       1553
# Loaned From                 16943
# Contract Valid Until          289
# Height                         48
# Weight                         48
# Release Clause                  0
# Release Clause_m             9057
# Release Clause_k            10714
# dtype: int64

# %%
(fifa.isnull().sum()/len(fifa))*100
# Out:
# Name                         0.000000
# Age                          0.000000
# Overall                      0.000000
# Potential                    0.000000
# Club                         1.323667
# Value                        0.000000
# Wage                         0.000000
# International Reputation     0.263635
# Skill Moves                  0.263635
# Work Rate                    0.263635
# Body Type                    0.263635
# Position                     0.329544
# Joined                       8.529686
# Loaned From                 93.057615
# Contract Valid Until         1.587302
# Height                       0.263635
# Weight                       0.263635
# Release Clause               0.000000
# Release Clause_m            49.744604
# Release Clause_k            58.845499
# dtype: float64

# %%
fifa=fifa.drop('Release Clause_m',axis=1)
fifa=fifa.drop('Release Clause_k',axis=1)

# %%
fifa.isnull().sum()
# Out:
# Name                            0
# Age                             0
# Overall                         0
# Potential                       0
# Club                          241
# Value                           0
# Wage                            0
# International Reputation       48
# Skill Moves                    48
# Work Rate                      48
# Body Type                      48
# Position                       60
# Joined                       1553
# Loaned From                 16943
# Contract Valid Until          289
# Height                         48
# Weight                         48
# Release Clause                  0
# dtype: int64

# %%
fifa=fifa.drop('Loaned From',axis=1)

# %%
(fifa.isnull().sum()/len(fifa))*100
# Out:
# Name                        0.000000
# Age                         0.000000
# Overall                     0.000000
# Potential                   0.000000
# Club                        1.323667
# Value                       0.000000
# Wage                        0.000000
# International Reputation    0.263635
# Skill Moves                 0.263635
# Work Rate                   0.263635
# Body Type                   0.263635
# Position                    0.329544
# Joined                      8.529686
# Contract Valid Until        1.587302
# Height                      0.263635
# Weight                      0.263635
# Release Clause              0.000000
# dtype: float64

# %%
fifa['International Reputation']=fifa['International Reputation'].fillna(fifa['International Reputation'].mean())

# %%
fifa['Skill Moves']=fifa['Skill Moves'].fillna(fifa['Skill Moves'].mean())

# %%
fifa.isnull().sum()
# Out:
# Name                           0
# Age                            0
# Overall                        0
# Potential                      0
# Club                         241
# Value                          0
# Wage                           0
# International Reputation       0
# Skill Moves                    0
# Work Rate                     48
# Body Type                     48
# Position                      60
# Joined                      1553
# Contract Valid Until         289
# Height                        48
# Weight                        48
# Release Clause                 0
# dtype: int64

# %%
fifa['Joined']=fifa['Joined'].astype(int,errors='ignore')

# %%
fifa['Joined']=fifa['Joined'].fillna(fifa['Joined'].mean())

# %%
fifa.head(5)
# Out:
#                 Name  Age  Overall  Potential                 Club  \
# 0           L. Messi   31       94         94         FC Barcelona
# 1  Cristiano Ronaldo   33       94         94             Juventus
# 2          Neymar Jr   26       92         93  Paris Saint-Germain
# 3             De Gea   27       91         93    Manchester United
# 4       K. De Bruyne   27       91         92      Manchester City
#
#          Value      Wage  International Reputation  Skill Moves  \
# 0  110500000.0  565000.0                       5.0          4.0
# 1   77000000.0  405000.0                       5.0          5.0
# 2  118500000.0  290000.0                       5.0          5.0
# 3   72000000.0  260000.0                       4.0          1.0
# 4  102000000.0  355000.0                       4.0          4.0
#
#         Work Rate   Body Type Position  Joined Contract Valid Until  Height  \
# 0  Medium/ Medium       Messi       RF  2004.0           2021-01-01    5.70
# ...

# %%
plt.figure(figsize=(10,6))
sns.distplot(fifa['Overall'])
plt.xlabel("Player scores")
plt.ylabel("number  of players")
plt.title("Histogram of overall rating")
plt.show()

# %%
sns.pairplot(fifa[['Overall','Value','Wage','International Reputation','Height','Weight','Release Clause']])
plt.show()

# %%
expire =  fifa.loc[fifa["Contract Valid Until"].dt.year == 2020.0, fifa.columns]
players=expire.sort_values('Overall',ascending=False)

# %%
top_players=players[:20]

# %%
top_players
# Out:
#                 Name  Age  Overall  Potential                 Club  \
# 3             De Gea   27       91         93    Manchester United
# 6          L. Modrić   32       91         91          Real Madrid
# 8       Sergio Ramos   32       91         91          Real Madrid
# 5          E. Hazard   27       91         91              Chelsea
# 13       David Silva   32       90         90      Manchester City
# 21         E. Cavani   31       89         89  Paris Saint-Germain
# 24      G. Chiellini   33       89         89             Juventus
# 31        C. Eriksen   26       88         91    Tottenham Hotspur
# 39      Thiago Silva   33       88         88  Paris Saint-Germain
# 50        D. Mertens   31       87         87               Napoli
# 52         M. Hamšík   30       87         87               Napoli
# 49        Jordi Alba   29       87         87         FC Barcelona
# 46          K. Navas   31       87         87          Real Madrid
# ...

# %%
top_players['Wage'].mean()
# Out:
# 205450.0

# %%
top_players['Age'].mean()
# Out:
# 30.65

# %%
top_players.corr()
# Out:
#                                Age   Overall  Potential     Value      Wage  \
# Age                       1.000000 -0.226913  -0.404930 -0.665962 -0.224665
# Overall                  -0.226913  1.000000   0.945065  0.786717  0.868755
# Potential                -0.404930  0.945065   1.000000  0.842004  0.784630
# Value                    -0.665962  0.786717   0.842004  1.000000  0.689820
# Wage                     -0.224665  0.868755   0.784630  0.689820  1.000000
# International Reputation  0.076763  0.877058   0.762655  0.516209  0.686910
# Skill Moves              -0.199300  0.337812   0.295973  0.536622  0.419355
# Joined                   -0.043249 -0.648116  -0.562374 -0.306153 -0.508650
# Height                    0.358728  0.178365   0.115154 -0.097510 -0.086814
# Weight                    0.167496 -0.257796  -0.228312 -0.372793 -0.369517
# Release Clause           -0.638870  0.812519   0.869849  0.991875  0.742504
#
# ...

# %%
sns.heatmap(top_players[['Overall','Value']].corr(),annot=True)
plt.show()

# %%
group=fifa.groupby('Position')[['Position','Name','Overall','Wage']].head()

# %%
group['Position'].unique()
# Out:
# array(['RF', 'ST', 'LW', 'GK', 'RCM', 'LF', 'RS', 'RCB', 'LCM', 'CB',
#        'LDM', 'CAM', 'CDM', 'LS', 'LCB', 'RM', 'LAM', 'LM', 'LB', 'RDM',
#        'RW', 'CM', 'RB', 'RAM', 'CF', 'RWB', 'LWB', nan], dtype=object)

# %%
group.sort_values(['Overall','Position'],ascending=False)
# Out:
#       Position               Name  Overall      Wage
# 1           ST  Cristiano Ronaldo       94  405000.0
# 0           RF           L. Messi       94  565000.0
# 2           LW          Neymar Jr       92  290000.0
# 7           RS          L. Suárez       91  455000.0
# 4          RCM       K. De Bruyne       91  355000.0
# ...        ...                ...      ...       ...
# 5018       NaN          R. Raldes       70       0.0
# 6736       NaN            J. Arce       68       0.0
# 7922       NaN       L. Gutiérrez       67       0.0
# 9905       NaN          R. Vargas       66       0.0
# 10628      NaN        D. Bejarano       65       0.0
#
# [140 rows x 4 columns]

# %%
from IPython.display import display

# %%
for i in range(0,27):
    fifa2=fifa[fifa['Position']==fifa['Position'].unique()[i]]
    fifa3=fifa2.sort_values('Overall',ascending=False).iloc[0:5,:]
    a=pd.DataFrame(fifa3)
    display(a)
# Out:
#              Name  Age  Overall  Potential              Club        Value  \
# 0        L. Messi   31       94         94      FC Barcelona  110500000.0
# 50     D. Mertens   31       87         87            Napoli   45000000.0
# 528     D. Valeri   32       80         80  Portland Timbers   11500000.0
# 890   L. Podolski   33       78         78       Vissel Kobe    6500000.0
# 1774     C. Ciano   28       75         75         Frosinone    6500000.0
#
#           Wage  International Reputation  Skill Moves       Work Rate  \
# 0     565000.0                       5.0          4.0  Medium/ Medium
# 50    135000.0                       3.0          4.0       High/ Low
# 528    12000.0                       2.0          3.0    High/ Medium
# 890    11000.0                       3.0          4.0     Medium/ Low
# 1774   17000.0                       1.0          4.0    High/ Medium
#
#      Body Type Position  Joined Contract Valid Until  Height  Weight  \
# ...

# %%
top=group['Name'].value_counts()

# %%
top
# Out:
# Illarramendi       1
# T. Müller          1
# M. Hamšík          1
# F. Thauvin         1
# D. De Rossi        1
#                   ..
# A. Di María        1
# R. Mahrez          1
# Bruno Fernandes    1
# Fabinho            1
# Coutinho           1
# Name: Name, Length: 140, dtype: int64

# %% [markdown]
# There is no repitition

# %%
avg_wage=group.groupby(['Position'])[['Position','Wage']].mean()
avg_wage.T
# Out:
# Position       CAM        CB       CDM       CF        CM        GK      LAM  \
# Wage      174000.0  139600.0  217000.0  47400.0  130600.0  192800.0  81600.0
#
# Position        LB       LCB       LCM  ...        RB       RCB       RCM  \
# Wage      177200.0  162000.0  184400.0  ...  155400.0  231000.0  240800.0
#
# Position       RDM        RF        RM        RS        RW      RWB        ST
# Wage      105000.0  148000.0  131400.0  132200.0  202000.0  44200.0  294000.0
#
# [1 rows x 27 columns]

# %%
fifa.head()
# Out:
#                 Name  Age  Overall  Potential                 Club  \
# 0           L. Messi   31       94         94         FC Barcelona
# 1  Cristiano Ronaldo   33       94         94             Juventus
# 2          Neymar Jr   26       92         93  Paris Saint-Germain
# 3             De Gea   27       91         93    Manchester United
# 4       K. De Bruyne   27       91         92      Manchester City
#
#          Value      Wage  International Reputation  Skill Moves  \
# 0  110500000.0  565000.0                       5.0          4.0
# 1   77000000.0  405000.0                       5.0          5.0
# 2  118500000.0  290000.0                       5.0          5.0
# 3   72000000.0  260000.0                       4.0          1.0
# 4  102000000.0  355000.0                       4.0          4.0
#
#         Work Rate   Body Type Position  Joined Contract Valid Until  Height  \
# 0  Medium/ Medium       Messi       RF  2004.0           2021-01-01    5.70
# ...

# %%
fifa_all=pd.read_csv(r"C:\Users\shank\Downloads\fifa.csv")

# %%
fifa_all.columns
# Out:
# Index(['ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag', 'Overall',
#        'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Preferred Foot',
#        'International Reputation', 'Weak Foot', 'Skill Moves', 'Work Rate',
#        'Body Type', 'Position', 'Jersey Number', 'Joined', 'Loaned From',
#        'Contract Valid Until', 'Height', 'Weight', 'Crossing', 'Finishing',
#        'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling', 'Curve',
#        'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
#        'Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving', 'GKHandling',
#        'GKKicking', 'GKPositioning', 'GKReflexes', 'Release Clause'],
#       dtype='object')

# %%
fifa_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 60 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        18207 non-null  int64
#  1   Name                      18207 non-null  object
#  2   Age                       18207 non-null  int64
#  3   Photo                     18207 non-null  object
#  4   Nationality               18207 non-null  object
#  5   Flag                      18207 non-null  object
#  6   Overall                   18207 non-null  int64
#  7   Potential                 18207 non-null  int64
#  8   Club                      17966 non-null  object
#  9   Club Logo                 18207 non-null  object
#  10  Value                     18207 non-null  object
#  11  Wage                      18207 non-null  object
#  12  Preferred Foot            18159 non-null  object
# ...

# %%
fifa_all.describe()
# Out:
#                   ID           Age       Overall     Potential  \
# count   18207.000000  18207.000000  18207.000000  18207.000000
# mean   214298.338606     25.122206     66.238699     71.307299
# std     29965.244204      4.669943      6.908930      6.136496
# min        16.000000     16.000000     46.000000     48.000000
# 25%    200315.500000     21.000000     62.000000     67.000000
# 50%    221759.000000     25.000000     66.000000     71.000000
# 75%    236529.500000     28.000000     71.000000     75.000000
# max    246620.000000     45.000000     94.000000     95.000000
#
#        International Reputation     Weak Foot   Skill Moves  Jersey Number  \
# count              18159.000000  18159.000000  18159.000000   18147.000000
# mean                   1.113222      2.947299      2.361308      19.546096
# std                    0.394031      0.660456      0.756164      15.947765
# min                    1.000000      1.000000      1.000000       1.000000
# ...

# %%
for i in fifa_all.columns:
    print(fifa_all[i].value_counts())
# Out:
# 231423    1
# 225883    1
# 205393    1
# 244306    1
# 209491    1
#          ..
# 244973    1
# 177388    1
# 199915    1
# 234728    1
# 198657    1
# Name: ID, Length: 18207, dtype: int64
# J. Rodríguez    11
# Paulinho         8
# J. Williams      7
# R. Williams      7
# Felipe           6
#                 ..
# T. Freriks       1
# G. Diangana      1
# R. Bertrand      1
# D. Tomii         1
# N. Hansen        1
# Name: Name, Length: 17194, dtype: int64
# 21    1423
# 26    1387
# 24    1358
# 22    1340
# 23    1332
# 25    1319
# 20    1240
# 27    1162
# 28    1101
# 19    1024
# 29     959
# 30     917
# 18     732
# 31     707
# 32     574
# 33     408
# 34     404
# 17     289
# 35     196
# 36     127
# 37      82
# 16      42
# 38      37
# 39      25
# 40      13
# 41       5
# 44       2
# 42       1
# 45       1
# Name: Age, dtype: int64
# https://cdn.sofifa.org/players/4/19/209407.png    1
# https://cdn.sofifa.org/players/4/19/214327.png    1
# ...

# %%
fifa_all.groupby(['Club'])['Overall','Club','Name'].head()
# Out:
#        Overall                 Club               Name
# 0           94         FC Barcelona           L. Messi
# 1           94             Juventus  Cristiano Ronaldo
# 2           92  Paris Saint-Germain          Neymar Jr
# 3           91    Manchester United             De Gea
# 4           91      Manchester City       K. De Bruyne
# ...        ...                  ...                ...
# 16354       57       Bray Wanderers         P. O'Conor
# 16367       57       Bray Wanderers           K. Lynch
# 16390       57       Bray Wanderers           C. Kenna
# 16753       56          Limerick FC        K. Cantwell
# 16846       56          Limerick FC           C. Ellis
#
# [3260 rows x 3 columns]

# %% [markdown]
# FC Barcelona is the club which has highest overall score

# %%
fifa[fifa['Club']=='FC Barcelona']
# Out:
#                   Name  Age  Overall  Potential          Club        Value  \
# 0             L. Messi   31       94         94  FC Barcelona  110500000.0
# 7            L. Suárez   31       91         91  FC Barcelona   80000000.0
# 18       M. ter Stegen   26       89         92  FC Barcelona   58000000.0
# 20     Sergio Busquets   29       89         89  FC Barcelona   51500000.0
# 32            Coutinho   26       88         89  FC Barcelona   69500000.0
# 42           S. Umtiti   24       87         92  FC Barcelona   57000000.0
# 49          Jordi Alba   29       87         87  FC Barcelona   38000000.0
# 53          I. Rakitić   30       87         87  FC Barcelona   46500000.0
# 54               Piqué   31       87         87  FC Barcelona   34000000.0
# 96            A. Vidal   31       85         85  FC Barcelona   26000000.0
# 155         O. Dembélé   21       83         92  FC Barcelona   40000000.0
# ...
